# %%
# import dependencies
import pandas as pd

# %%
# read in csv file
cities = pd.read_csv('cities.csv')

# %%
# preview to make sure df looks correct
cities.head()
# Out:
#    City_ID       City Country        Date      Lat       Lng  Max Temp  \
# 0        0   Lorengau      PG  1650487883  -2.0226  147.2712     82.58
# 1        1    Rikitea      PF  1650487883 -23.1203 -134.9692     78.60
# 2        2  Hithadhoo      MV  1650487884  -0.6000   73.0833     82.87
# 3        3   Baghmara      IN  1650487885  23.7950   86.2085     79.68
# 4        4     Torbay      CA  1650487885  47.6666  -52.7314     47.28
#
#    Humidity  Cloudiness  Wind Speed
# 0        72          61       11.03
# 1        72           2       19.53
# 2        70          97        3.67
# 3        78           0        8.75
# 4        88         100       33.38

# %%
# set index to City_ID
cities.set_index('City_ID', inplace=True)

# preview
cities.head()
# Out:
#               City Country        Date      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0         Lorengau      PG  1650487883  -2.0226  147.2712     82.58        72
# 1          Rikitea      PF  1650487883 -23.1203 -134.9692     78.60        72
# 2        Hithadhoo      MV  1650487884  -0.6000   73.0833     82.87        70
# 3         Baghmara      IN  1650487885  23.7950   86.2085     79.68        78
# 4           Torbay      CA  1650487885  47.6666  -52.7314     47.28        88
#
#          Cloudiness  Wind Speed
# City_ID
# 0                61       11.03
# 1                 2       19.53
# 2                97        3.67
# 3                 0        8.75
# 4               100       33.38

# %%
# export to html
cities.to_html("cities.html")
